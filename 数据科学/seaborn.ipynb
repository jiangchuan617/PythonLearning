# %% [markdown]
# ## seaborn

# %% [markdown]
# ### 用seaborn实现直方图和密度图

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# 在jupyter中需要添加下面的语句
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
s1 = pd.Series(np.random.randn(1000))
# Out:
# 0      1.705188
# 1      0.530343
# 2     -1.211638
# 3      2.032317
# 4     -0.358148
#          ...
# 995   -0.521141
# 996    1.093518
# 997    0.519576
# 998    1.688081
# 999   -0.751940
# Length: 1000, dtype: float64

# %%
plt.hist(s1)
# Out:
# (array([  1.,   4.,  17.,  74., 206., 273., 253., 130.,  35.,   7.]),
#  array([-4.22213613, -3.47573266, -2.72932919, -1.98292572, -1.23652225,
#         -0.49011877,  0.2562847 ,  1.00268817,  1.74909164,  2.49549511,
#          3.24189859]),
#  <a list of 10 Patch objects>)

# %%
s1.plot(kind = "kde")

# %%
sns.distplot(s1, hist=True, kde=True,rug=True)

# %%
sns.kdeplot(s1, shade = True,color='g')

# %% [markdown]
# ### 用seaborn 实现柱状图和热力图

# %%
df = sns.load_dataset("flights")
# 网络不好的话 复制 https://github.com/mwaskom/seaborn-data/blob/master/flights.csv
# df = pd.read_clipboard()
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
df.shape
# Out:
# (144, 3)

# %%
df = df.pivot(index="month", columns="year", values="passengers")
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(df)

# %%
sns.heatmap(df, annot=True, fmt="d")

# %%
df
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
s = df.sum()
# Out:
# year
# 1949    1520
# 1950    1676
# 1951    2042
# 1952    2364
# 1953    2700
# 1954    2867
# 1955    3408
# 1956    3939
# 1957    4421
# 1958    4572
# 1959    5140
# 1960    5714
# dtype: int64

# %%
sns.barplot(s.index,s.values)

# %% [markdown]
# ### seaborn 设置图形显示效果

# %%
x = np.linspace(0,14,100)
y1 = np.sin(x)
y2 = np.sin(x+2)*1.25;

# %%
def sinplot():
    plt.plot(x,y1)
    plt.plot(x,y2)

# %%
sinplot()

# %%
styles = ['darkgrid','dark','white','whitegrid','ticks']
sns.set_style(styles[0])
sinplot()

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': '#EAEAF2',
#  'axes.edgecolor': 'white',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'patch.force_edgecolor': True,
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
sns.set_style(styles[0], {'grid.color': 'red'})
sinplot()

# %%
sns.set() # 清空更改风格
sinplot()

# %%
contexts = ['paper', 'notebook', 'talk', 'poster']
# Out:
# ['paper', 'notebook', 'talk', 'poster']

# %%
sns.set_context(contexts[2])
sinplot()

# %%
sns.plotting_context()
# Out:
# {'font.size': 18.0,
#  'axes.labelsize': 18.0,
#  'axes.titlesize': 18.0,
#  'xtick.labelsize': 16.5,
#  'ytick.labelsize': 16.5,
#  'legend.fontsize': 16.5,
#  'axes.linewidth': 1.875,
#  'grid.linewidth': 1.5,
#  'lines.linewidth': 2.25,
#  'lines.markersize': 9.0,
#  'patch.linewidth': 1.5,
#  'xtick.major.width': 1.875,
#  'ytick.major.width': 1.875,
#  'xtick.minor.width': 1.5,
#  'ytick.minor.width': 1.5,
#  'xtick.major.size': 9.0,
#  'ytick.major.size': 9.0,
#  'xtick.minor.size': 6.0,
#  'ytick.minor.size': 6.0}

# %%
sns.set_context(contexts[2], rc={'grid.linewidth': 4.0})
sinplot()

# %%
sns.set() # 恢复默认

# %% [markdown]
# ### seaborn 调色功能

# %%
def sinplot():
    x = np.linspace(0, 14, 100)
    plt.figure(figsize=(8,6))
    for i in range(4):
        plt.plot(x, np.sin(x+i)*(i+0.75), label='sin(x+%s)*(%s+0.75)' % (i, i))
    plt.legend()

# %%
sinplot()

# %%
# 调色板
sns.color_palette()  # RGB
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]

# %%
sns.palplot(sns.color_palette())

# %%
pal_style = ["deep",'muted','pastel','bright','dark','colorblind']
# sns.palplot(sns.color_palette("deep"))
sns.palplot(sns.color_palette(pal_style[5]))

# %%
sns.set_palette(sns.color_palette("dark"))

# %%
sinplot()

# %%
sns.set()

# %%
with sns.color_palette("dark"):
    sinplot()

# %%
pal1 = sns.color_palette([(0.5,0.1,0.7),(0.3,0.1,0.9)])
sns.palplot(pal1)

# %%
pal2 = sns.color_palette("hls",8)
sns.palplot(pal2)
